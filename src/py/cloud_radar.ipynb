# %%
import requests
from bs4 import BeautifulSoup
import csv
import json

# %%
r = requests.get('https://www.jma.go.jp/jp/highresorad/')

# %%
r.encoding = r.apparent_encoding
soup = BeautifulSoup(r.text)

# %%
rows = soup.findAll('body',class_='vsc-initialized')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!--[if lt IE 9]>
#     <meta http-equiv="X-UA-Compatible" content="IE=7" />
#   <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--<![endif]-->
# <meta content="気象庁 Japan Meteorological Agency" name="Author"/>
# <meta content="気象庁,雨雲の動き,雨,雨雲,レーダー,レーダ,雷,竜巻,降水,分布" name="keywords"/>
# <meta content="このページでは、1時間先までの降水分布の予報をご覧いただけます。また、強い雨の領域や雷の活動度、竜巻発生の確度などを重ねて表示できます。" name="description"/>
# <title>気象庁 | 雨雲の動き（高解像度降水ナウキャスト）</title>
# <script type="text/javascript">
#   <!--
#     var ual = navigator.userAgent.toLowerCase();
#     if((/iphone/.test(ual) && !(/ipad/.test(ual)))
#         || /ipod/.test(ual)
#         || (/android/.test(ual) && /mobile/.test(ual))
#         || /blackberry/.test(ual)
#         || /windows\sphone/.test(ual)
#         || /windows\sce/.test(ual)) {
# ...

# %%
print(rows)
# Out:
# []
